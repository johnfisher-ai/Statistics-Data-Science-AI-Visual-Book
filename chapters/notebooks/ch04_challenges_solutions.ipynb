# %% [markdown]
# <div style="background:linear-gradient(135deg,#7a3d00 0%,#b45309 55%,#d97706 100%);border-radius:18px;padding:34px 30px;color:#fff;font-family:Inter,Segoe UI,sans-serif">
#   <div style="font-size:12px;letter-spacing:3px;color:#ffe9c7;font-weight:700;text-transform:uppercase">Chapter 4 · Solutions</div>
#   <div style="font-size:36px;font-weight:900;line-height:1.1;margin:10px 0 6px">Practice Challenges, Worked Answers ✅</div>
#   <div style="font-size:15px;color:#ffe6cc;max-width:700px;line-height:1.6">Full solutions to the four "Types of Data &amp; Variables" challenges. Try them yourself first, then compare.</div>
#   <div style="margin-top:16px;font-size:13px;color:#ffe2bf">Statistics, Data Science and AI: A Visual Handbook · John Fisher · 2026</div>
# </div>

# %% [markdown]
# ## ⚙️ Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
NAVY="#0a1230"; INK="#1a2138"; INK_SOFT="#4a5578"
CYAN="#0891b2"; PURPLE="#7c3aed"; AMBER="#d97706"; GREEN="#059669"; PINK="#db2777"; BLUE="#2563eb"; GRID="#e6e9f2"
plt.rcParams.update({
    "figure.facecolor":"white","axes.facecolor":"white","figure.dpi":110,"font.size":11,
    "axes.edgecolor":GRID,"axes.linewidth":1.2,"axes.grid":True,"grid.color":GRID,"axes.axisbelow":True,
    "axes.spines.top":False,"axes.spines.right":False,"axes.titlesize":14,"axes.titleweight":"bold","axes.titlecolor":INK,
    "axes.labelcolor":INK_SOFT,"xtick.color":INK_SOFT,"ytick.color":INK_SOFT,"legend.frameon":False})
print("✅ Ready.")
# Out:
# ✅ Ready.

# %% [markdown]
# <div style="background:#fef3e2;border-left:5px solid #d97706;border-radius:10px;padding:16px 20px;font-family:Inter,sans-serif">
# <span style="font-size:13px;font-weight:800;color:#0891b2;letter-spacing:1px">CHALLENGE 1 · CLASSIFY</span>
# <div style="font-size:21px;font-weight:800;color:#1a2138;margin-top:4px">Name each variable's type</div>
# <div style="color:#4a5578;margin-top:6px">For each variable, give the big type (qualitative/quantitative) and subtype (nominal/ordinal/discrete/continuous): age, eye color, number of siblings, temperature, T-shirt size (S/M/L).</div>
# </div>

# %%
answer = pd.DataFrame({
    "variable":["age","eye color","number of siblings","temperature","T-shirt size"],
    "big type":["Quantitative","Qualitative","Quantitative","Quantitative","Qualitative"],
    "subtype": ["Continuous","Nominal","Discrete","Continuous","Ordinal"],
    "why":     ["measured, any value","categories, no order","counted whole numbers",
                "measured, any value","categories WITH an order S<M<L"],
})
answer
# Out:
#              variable      big type     subtype  \
# 0                 age  Quantitative  Continuous
# 1           eye color   Qualitative     Nominal
# 2  number of siblings  Quantitative    Discrete
# 3         temperature  Quantitative  Continuous
# 4        T-shirt size   Qualitative     Ordinal
#
#                               why
# 0             measured, any value
# 1            categories, no order
# 2           counted whole numbers
# 3             measured, any value
# 4  categories WITH an order S<M<L

# %% [markdown]
# **Answer:** the trick is two questions, *is it a number you can do math on?* (quantitative vs qualitative), then *countable or measurable?* / *ordered or not?* T-shirt size is the classic "looks like a category but has order" → **ordinal**.

# %% [markdown]
# <div style="background:#fef3e2;border-left:5px solid #d97706;border-radius:10px;padding:16px 20px;font-family:Inter,sans-serif">
# <span style="font-size:13px;font-weight:800;color:#7c3aed;letter-spacing:1px">CHALLENGE 2 · SPLIT THE COLUMNS</span>
# <div style="font-size:21px;font-weight:800;color:#1a2138;margin-top:4px">Separate qualitative from quantitative</div>
# <div style="color:#4a5578;margin-top:6px">Given this customer table, list which columns are qualitative and which are quantitative.</div>
# </div>

# %%
customers = pd.DataFrame({
    "city":      ["Lagos","Cairo","Lagos","Nairobi"],
    "age":       [25, 41, 33, 29],
    "plan":      ["Free","Pro","Pro","Free"],
    "monthly_$": [0.0, 12.99, 12.99, 0.0],
})
qualitative  = [c for c in customers.columns if customers[c].dtype == "object"]
quantitative = [c for c in customers.columns if customers[c].dtype != "object"]
print("Qualitative  (categories):", qualitative)
print("Quantitative (numbers)   :", quantitative)
# Out:
# Qualitative  (categories): []
# Quantitative (numbers)   : ['city', 'age', 'plan', 'monthly_$']

# %% [markdown]
# **Answer:** Qualitative → `city`, `plan` (text categories). Quantitative → `age`, `monthly_$` (numbers). A quick first pass: pandas stores text categories as the `object` dtype.

# %% [markdown]
# <div style="background:#fef3e2;border-left:5px solid #d97706;border-radius:10px;padding:16px 20px;font-family:Inter,sans-serif">
# <span style="font-size:13px;font-weight:800;color:#d97706;letter-spacing:1px">CHALLENGE 3 · DISCRETE OR CONTINUOUS</span>
# <div style="font-size:21px;font-weight:800;color:#1a2138;margin-top:4px">Decide for each</div>
# <div style="color:#4a5578;margin-top:6px">Label each as discrete or continuous: cars in a parking lot, weight of a parcel, goals scored in a match, time to run 5 km.</div>
# </div>

# %%
items = {
    "cars in a parking lot": "Discrete (counted, whole numbers)",
    "weight of a parcel":    "Continuous (measured, any value)",
    "goals scored":          "Discrete (counted, whole numbers)",
    "time to run 5 km":      "Continuous (measured, any value)",
}
for k, v in items.items():
    print(f"{k:<24} -> {v}")
# Out:
# cars in a parking lot    -> Discrete (counted, whole numbers)
# weight of a parcel       -> Continuous (measured, any value)
# goals scored             -> Discrete (counted, whole numbers)
# time to run 5 km         -> Continuous (measured, any value)

# %% [markdown]
# **Answer:** if you **count** it (cars, goals) it's **discrete**; if you **measure** it (weight, time) it's **continuous**. A handy test: continuous values can always have more decimal places.

# %% [markdown]
# <div style="background:#fef3e2;border-left:5px solid #d97706;border-radius:10px;padding:16px 20px;font-family:Inter,sans-serif">
# <span style="font-size:13px;font-weight:800;color:#2563eb;letter-spacing:1px">CHALLENGE 4 · VARIABLE ROLES</span>
# <div style="font-size:21px;font-weight:800;color:#1a2138;margin-top:4px">Find IV, DV, and a confounder</div>
# <div style="color:#4a5578;margin-top:6px">Study: "Does the amount of fertilizer affect plant height?" Identify the independent variable, the dependent variable, and one possible confounder.</div>
# </div>

# %%
roles = {
    "Independent variable (cause)": "amount of fertilizer",
    "Dependent variable (effect)":  "plant height",
    "Possible confounder":          "sunlight (affects growth AND may vary by plot)",
}
for k, v in roles.items():
    print(f"{k:<32}: {v}")
# Out:
# Independent variable (cause)    : amount of fertilizer
# Dependent variable (effect)     : plant height
# Possible confounder             : sunlight (affects growth AND may vary by plot)

# %% [markdown]
# **Answer:** IV = fertilizer (what we change), DV = plant height (what we measure). A **confounder** like sunlight or watering could influence height too, so a fair experiment must hold those constant. IV → DV, with confounders controlled.

# %% [markdown]
# ---
# <div style="background:#ffffff;border:1px solid #e6e9f2;border-radius:16px;padding:22px 26px;font-family:Inter,sans-serif">
# <div style="font-size:19px;font-weight:800;color:#1a2138">🎉 Nicely done!</div>
# <div style="color:#4a5578;line-height:1.8;margin-top:8px">You classified variables, split qualitative from quantitative, told discrete from continuous, and identified cause, effect, and a confounder, the vocabulary every later chapter assumes.</div>
# </div>
#
# <div style="text-align:center;color:#8b94b3;font-size:12px;margin-top:16px">Statistics, Data Science and AI: A Visual Handbook · © 2026 John Fisher</div>
