# %% [markdown]
# <div style="background:linear-gradient(135deg,#1e1b4b 0%,#4338ca 55%,#6366f1 100%);border-radius:18px;padding:30px 30px;color:#fff;font-family:Inter,Segoe UI,sans-serif">
#   <div style="font-size:12px;letter-spacing:3px;color:#c7d2fe;font-weight:700;text-transform:uppercase">Solutions</div>
#   <div style="font-size:30px;font-weight:900;line-height:1.1;margin:10px 0 6px">Hypothesis Logic — Worked Solutions ✅</div>
#   <div style="font-size:14px;color:#eef2ff;max-width:740px;line-height:1.6">Five challenges, each verified in code.</div>
#
# </div>

# %% [markdown]
# ## ⚙️ Setup

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from scipy import stats
IND="#4f46e5"; DEEP="#4338ca"; LIGHT="#818cf8"; INK="#1a2138"; GRID="#e6e9f2"; GREEN="#059669"; RED="#ef4444"
BASE="https://raw.githubusercontent.com/johnfisher-ai/Statistics-Data-Science-AI-Visual-Book/main/data/"
rng = np.random.default_rng(74)
rng = np.random.default_rng(740)

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 1</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">State the hypotheses</div>
# <div style="color:#4a5578;margin-top:5px">A coach claims a drill raises free-throw % above 70%. Write H0 and H1 and say which is one-sided.</div>
# </div>

# %%
print("H0: p = 0.70 (no improvement)")
print("H1: p > 0.70 (the drill helps) -> ONE-SIDED, upper tail")
print("We reject H0 only if the data fall far enough into the upper tail.")
# Out:
# H0: p = 0.70 (no improvement)
# H1: p > 0.70 (the drill helps) -> ONE-SIDED, upper tail
# We reject H0 only if the data fall far enough into the upper tail.

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 2</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">Build a null distribution</div>
# <div style="color:#4a5578;margin-top:5px">Simulate 50 fair coins, 20,000 times, and find the 2.5th/97.5th percentiles of the heads-fraction.</div>
# </div>

# %%
sim = rng.binomial(50, 0.5, 20000)/50
lo,hi = np.percentile(sim,[2.5,97.5])
print(f"under H0, 95% of fair-coin results fall in [{lo:.2f}, {hi:.2f}]; outside that is surprising")
# Out:
# under H0, 95% of fair-coin results fall in [0.36, 0.64]; outside that is surprising

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 3</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">Compute a p-value by simulation</div>
# <div style="color:#4a5578;margin-top:5px">Observed 33 heads in 50 tosses. Two-sided p-value under a fair coin, by simulation.</div>
# </div>

# %%
phat=33/50; sim=rng.binomial(50,0.5,200000)/50
p=np.mean(np.abs(sim-0.5) >= abs(phat-0.5))
print(f"phat={phat:.2f}, two-sided p-value = {p:.4f}")
print("reject H0 at 5%" if p<0.05 else "fail to reject H0 at 5%")
# Out:
# phat=0.66, two-sided p-value = 0.0243
# reject H0 at 5%

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 4</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">One-sample t-test from scratch</div>
# <div style="color:#4a5578;margin-top:5px">For a sample of 40 with mean 51.2 and sd 9, test H0: mu=50 (two-sided). Compute t and the p-value, then check with scipy.</div>
# </div>

# %%
xbar,s,n,mu0=51.2,9.0,40,50.0; se=s/np.sqrt(n); t=(xbar-mu0)/se
p=2*(1-stats.t.cdf(abs(t),n-1))
print(f"t={t:.3f}, df={n-1}, p={p:.4f}")
x=rng.normal(51.2,9,40); x=(x-x.mean())/x.std(ddof=1)*9+51.2  # force mean/sd
print(f"scipy on a matched sample: t={stats.ttest_1samp(x,50).statistic:.3f}, p={stats.ttest_1samp(x,50).pvalue:.4f}")
# Out:
# t=0.843, df=39, p=0.4042
# scipy on a matched sample: t=0.843, p=0.4042

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 5</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">Real data: the short-fill test</div>
# <div style="color:#4a5578;margin-top:5px">Load ch74_factory_fills.xlsx and run the one-sided one-sample t-test of H0: mu = 500.</div>
# </div>

# %%
try:    fills = pd.read_excel("../../data/ch74_factory_fills.xlsx", sheet_name="Fills")
except FileNotFoundError: fills = pd.read_excel(BASE+"ch74_factory_fills.xlsx", sheet_name="Fills")
x=fills.fill_ml; res=stats.ttest_1samp(x,500)
print(f"n={len(x)}, mean={x.mean():.2f}, t={res.statistic:.2f}, one-sided p={res.pvalue/2:.4f}")
print("reject H0: the line under-fills" if res.pvalue/2<0.05 else "fail to reject")
# Out:
# n=45, mean=498.07, t=-2.57, one-sided p=0.0069
# reject H0: the line under-fills

# %% [markdown]
# ---
# <div style="text-align:center;color:#8b94b3;font-size:12px;margin-top:10px">Statistics, Data Science and AI: A Visual Handbook · © 2026 John Fisher</div>
