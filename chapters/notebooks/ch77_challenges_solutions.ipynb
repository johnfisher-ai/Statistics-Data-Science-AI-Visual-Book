# %% [markdown]
# <div style="background:linear-gradient(135deg,#1e1b4b 0%,#4338ca 55%,#6366f1 100%);border-radius:18px;padding:30px 30px;color:#fff;font-family:Inter,Segoe UI,sans-serif">
#   <div style="font-size:12px;letter-spacing:3px;color:#c7d2fe;font-weight:700;text-transform:uppercase">Chapter 77 · Solutions</div>
#   <div style="font-size:30px;font-weight:900;line-height:1.1;margin:10px 0 6px">t-Tests — Worked Solutions ✅</div>
#   <div style="font-size:14px;color:#eef2ff;max-width:740px;line-height:1.6">Five challenges, each verified in code.</div>
#
# </div>

# %% [markdown]
# ## ⚙️ Setup

# %%
import numpy as np, pandas as pd
from scipy import stats
BASE="https://raw.githubusercontent.com/johnfisher-ai/Statistics-Data-Science-AI-Visual-Book/main/data/"
rng=np.random.default_rng(770)

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 1</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">One-sample t-test</div>
# <div style="color:#4a5578;margin-top:5px">For a sample of 30 from N(48,10), test H0: mu = 50 (two-sided).</div>
# </div>

# %%
x=rng.normal(48,10,30); r=stats.ttest_1samp(x,50)
print(f"mean={x.mean():.2f}, t={r.statistic:.2f}, p={r.pvalue:.4f}")
# Out:
# mean=48.15, t=-0.96, p=0.3466

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 2</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">Welch two-sample t-test</div>
# <div style="color:#4a5578;margin-top:5px">Compare N(50,8,n=40) and N(54,14,n=45) with Welch's test.</div>
# </div>

# %%
a=rng.normal(50,8,40); b=rng.normal(54,14,45); r=stats.ttest_ind(a,b,equal_var=False)
print(f"meanA={a.mean():.2f}, meanB={b.mean():.2f}, t={r.statistic:.2f}, p={r.pvalue:.4f}")
# Out:
# meanA=49.38, meanB=52.33, t=-1.36, p=0.1771

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 3</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">Paired vs unpaired</div>
# <div style="color:#4a5578;margin-top:5px">Make before ~ N(100,15,n=30) and after = before - N(4,6). Compare paired and unpaired p-values.</div>
# </div>

# %%
before=rng.normal(100,15,30); after=before-rng.normal(4,6,30)
print(f"paired   p={stats.ttest_rel(after,before).pvalue:.4f}")
print(f"unpaired p={stats.ttest_ind(after,before,equal_var=False).pvalue:.4f}  (less powerful here)")
# Out:
# paired   p=0.0713
# unpaired p=0.6231  (less powerful here)

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 4</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">One-sided two-sample</div>
# <div style="color:#4a5578;margin-top:5px">For groups above, test H1: muB > muA (one-sided). Halve the two-sided p only if the direction matches.</div>
# </div>

# %%
a=rng.normal(50,8,40); b=rng.normal(54,10,45); r=stats.ttest_ind(b,a,equal_var=False)
p_one = r.pvalue/2 if r.statistic>0 else 1-r.pvalue/2
print(f"t={r.statistic:.2f}, one-sided p (muB>muA) = {p_one:.4f}")
# Out:
# t=0.59, one-sided p (muB>muA) = 0.2774

# %% [markdown]
# <div style="background:#eef2ff;border-left:5px solid #4f46e5;border-radius:10px;padding:14px 18px;font-family:Inter,sans-serif">
# <span style="font-size:12px;font-weight:800;color:#4338ca;letter-spacing:1px">CHALLENGE 5</span>
# <div style="font-size:18px;font-weight:800;color:#1a2138;margin-top:3px">Real data: three class tests</div>
# <div style="color:#4a5578;margin-top:5px">Load ch77_class_scores.xlsx; run the paired (post vs pre), two-sample (flipped vs traditional), and one-sample (gain vs 5) tests.</div>
# </div>

# %%
try:    sc = pd.read_excel("../../data/ch77_class_scores.xlsx", sheet_name="Scores")
except FileNotFoundError: sc = pd.read_excel(BASE+"ch77_class_scores.xlsx", sheet_name="Scores")
gain=sc.posttest-sc.pretest
print(f"paired p={stats.ttest_rel(sc.posttest,sc.pretest).pvalue:.2e}")
fl=sc[sc.method=="flipped"].posttest; tr=sc[sc.method=="traditional"].posttest
print(f"two-sample p={stats.ttest_ind(fl,tr,equal_var=False).pvalue:.2e}")
print(f"one-sample gain vs 5 p={stats.ttest_1samp(gain,5).pvalue:.2e}")
# Out:
# paired p=6.00e-31
# two-sample p=2.33e-05
# one-sample gain vs 5 p=2.71e-08

# %% [markdown]
# ---
# <div style="text-align:center;color:#8b94b3;font-size:12px;margin-top:10px">Statistics, Data Science and AI: A Visual Handbook · © 2026 John Fisher</div>
